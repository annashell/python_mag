# %% [markdown]
# <h1>Строки</h1>

# %% [markdown]
# Строки
# Строки в языке Python являются объектами типа str. Переменной можно присвоить значение, являющееся строкой, с помощью двойных или одинарных кавычек:
#
# S = "Hello"<br/>
# T = 'Hello'<br/>
#
# Строка считывается со стандартного ввода функцией input():
#
# S = input()<br/>
# Напомним, что для строк определены операции сложения (конкатенация) и умножения строки на число.

# %%
str = 'sfdjf jsdf sl'
str
# Out:
# 'sfdjf jsdf sl'

# %%
S = 'Hello ' +'World'
S
# Out:
# 'Hello World'

# %%
S = 'A' * 50
S
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA'

# %% [markdown]
# Узнать количество символов (длину строки) можно при помощи функции len():

# %%
S = 'Hello world'
print(len(S))
# Out:
# 11

# %% [markdown]
# <h2>Обращение по индексу</h2>
#
# Для получения одного символа строки используется обращение по индексу. Индексом называется номер символа в строке.
#
# Например, S[i] — это символ строки, который имеет индекс i, при этом нумерация начинается с числа 0. То есть если S = 'Hello', то S[0] == 'H', S[1] == 'e', S[2] == 'l', S[3] == 'l', S[4] == 'o'.

# %% [markdown]
# Если мы хотим обратиться к последнему элементу некоторой строки, то нужно сначала узнать её длину, после чего вычесть из полученного значения 1. Для нахождения длины используется функция len(S). Таким образом, последний элемент строки будет возвращаться функцией S[len(S) - 1]. Однако данная конструкция достаточно громоздка, вместо неё можно использовать отрицательные значения индексов.
#
# Если указать отрицательное значение индекса, то номер будет отсчитываться с конца, начиная с -1. То есть S = 'Hello', то S[-1] == 'o', S[-2] == 'l', S[-3] == 'l', S[-4] == 'e', S[-5] == 'H'.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Если же номер символа строки S больше либо равен len(S) или меньше чем -len(S), то при обращении к этому символу строки произойдёт ошибка IndexError: string index out of range.

# %% [markdown]
# Задача. Количество букв 'a' в строке <br/>
# Дана строка, необходимо посчитать количество букв 'a' в ней.

# %%
count = 0
S = input()
for i in range(len(S)):
    if S[i] == 'а':
        count += 1
print(count)
# Out:
# Раз два три
# 2

# %%
count = 0
S = input()
for c in S:
    if c == 'а':
        count += 1
print(count)
# Out:
# Раз два три
# 2

# %% [markdown]
# Задача. Дана строка, состоящая из n цифр (т. е. однозначных чисел), между которыми стоит n−1 знак операции, каждый из которых может быть либо +, либо −. Вычислите значение данного выражения.

# %%
s = input()
answer = int(s[0])

for i in range(2, len(s), 2):
  if s[i - 1] == '+':
    answer += int(s[i])
  else:
    answer -= int(s[i])

print(answer)
# Out:
# 2-3+7
# 6

# %% [markdown]
# <h2>Срезы</h2>
#
# Срез (slice) — извлечение из данной строки некоторого фрагмента подстроки или подпоследовательности символов.
#
# Срез можно создать таким образом: S[a : b]. Такой срез возвращает подстроку из b - a символов, начиная с символа c индексом a до символа с индексом b, не включая его. В этом случае a должно быть меньше b, иначе срез вернёт пустую строку. Будем рассматривать в качестве примера строку S = 'Abracadabra'. Для неё срез S[2 : 7] == 'racad'.
#
# Можно использовать как положительные, так и отрицательные индексы в одном срезе. Например, S[1 : -1] — это строка без первого и последнего символа (срез начинается с символа с индексом 1 и заканчивается индексом -1, не включая его). Для рассмотренной выше строки срез S[1 : -1] == 'bracadabr', а срез S[-6 : -2] == 'adab'.
#
# При использовании срезов ошибка IndexError никогда не возникает. Например, срез S[1 : 100000] вернёт строку 'bracadabra'.
#
# Можно не указывать второй параметр (но поставить двоеточие), тогда срез берётся до конца строки. Например, чтобы удалить из строки первый символ, можно взять срез S[1:]. Аналогично можно опустить первый параметр, тогда срез S[:5] берётся от начала строки до указанного параметра 5, не включая его. Срез S[:] совпадает с самой строкой S.

# %% [markdown]
# <h2>Срезы с тремя параметрами</h2>
#
# Пусть нам необходимо взять срез, в котором символы будут идти не подряд, а с некоторым шагом d. Тогда срез будет иметь три параметра: S[a : b : d]. Третий параметр задаёт шаг, как и в случае с функцией range(), то есть будут взяты символы с индексами a, a + d, a + 2 * d и так далее. Так, для рассмотренной выше строки S[2 : 9 : 2] вернёт строку 'rcdb'.
#
# Кроме того, параметры можно опускать. Например, срез S[ : : 2] вернёт символы с чётными индексами, а срез S[1 : : 2] — с нечётными. Кроме того, можно взять значение шага среза равным отрицательному числу, тогда символы будут идти в обратном порядке. Например, срез S[9 : 4 : -1] == 'rbada', а S[ : : -1] == 'arbadacarbA'.

# %% [markdown]
# Задача. <br/>
#
# Посчитайте заданные характеристики строки. Циклы использовать нельзя.
#
# Входные данные
#
# Дана строка, состоящая из строчных и прописных букв латинского алфавита.
#
# Выходные данные
#
# Сначала выведите третий символ этой строки.
#
# Во второй строке выведите предпоследний символ этой строки.
#
# В третьей строке выведите первые пять символов этой строки.
#
# В четвёртой строке выведите всю строку, кроме последних двух символов.
#
# В пятой строке выведите все символы с чётными индексами (считая, что индексация начинается с 0
# , поэтому символы выводятся начиная с первого).
#
# В шестой строке выведите все символы с нечётными индексами, то есть начиная со второго символа строки.
#
# В седьмой строке выведите все символы в обратном порядке.
#
# В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
#
# В девятой строке выведите длину данной строки.

# %%
s = input()

print(s[2])
print(s[-2])
print(s[:5])
print(s[:-2])
print(s[::2])
print(s[1::2])
print(s[::-1])
print(s[-1::-2])
print(len(s))
# Out:
# Abrakadabra
# r
# r
# Abrak
# Abrakadab
# Arkdba
# baaar
# arbadakarbA
# abdkrA
# 11

# %% [markdown]
# Задача. Напишите программу, которая определяет, является ли введённое слово (без пробелов) палиндромом, то есть верно ли, что оно читается одинаково слева направо и справа налево.

# %%
string = input()

if string == string[::1]:
  print(f"Строка {string} является палиндромом")
else:
  print(f"Строка {string} не является палиндромом")
# Out:
# арозаупаланалапуазора
# Строка арозаупаланалапуазора является палиндромом

# %% [markdown]
# Задача. Сначала чётные позиции, потом нечётные.
#
# Дана строка. Выведите на одной строке сначала символы, стоящие на чётных позициях, а потом — на нечётных.

# %%
string = input()

result = string[::2] + string[1::2]

print(result)
# Out:
# 123456
# 135246

# %% [markdown]
# <h2>Методы find и rfind</h2>
#
# Метод — это функция, применяемая к объекту, например к строке или числу. Метод вызывается в виде ИмяОбъекта.ИмяМетода(параметры).
#
# Рассмотрим методы find и rfind для работы со строками.
#
# Метод find находит в данной строке подстроку, которая передаётся в качестве параметра. Функция возвращает индекс первого (cамого левого) вхождения искомой подстроки. Если же подстрока не найдена, то метод возвращает значение -1. С помощью этого метода можно проверять, содержится ли подстрока в строке. Например:

# %%
S = 'Abracadabra'
print(S.find('abr'))
# Out:
# 7

# %%
print(S.find('Abr'))
# Out:
# 0

# %%
print(S.find('aa'))
# Out:
# -1

# %% [markdown]
# Аналогично метод rfind возвращает индекс последнего вхождения данной строки («поиск справа»).

# %%
print(S.rfind('a'))
# Out:
# 10

# %%
print(S.rfind('br'))
# Out:
# 8

# %% [markdown]
# Если вызвать метод find с тремя параметрами S.find(T, a, b), то поиск будет осуществляться в срезе S[a : b]. Если указать только два параметра S.find(T, a), то поиск будет осуществляться в срезе S[a : ], то есть начиная с символа с индексом a и до конца строки. Отметим, что метод S.find(T, a, b) возвращает индекс в строке S, а не индекс относительно начала среза. Например:

# %%
print(S.find('a', 2, 8))
# Out:
# 3

# %%
S[2:]
# Out:
# 'racadabra'

# %%
print(S.find('b', 2))
# Out:
# 8

# %% [markdown]
# <h2>Методы count и replace</h2>
#
# Метод count
#
# Подсчитывает количество вхождений одной строки в другую строку. Простейшая форма вызова S.count(T) возвращает число вхождений строки T внутри строки S. При этом подсчитываются только непересекающиеся вхождения, например:

# %%
S = 'Abracadabra'
print(S.count('a'))
# Out:
# 4

# %%
print(S.count('ra'))
# Out:
# 2

# %%
S = 'aaaaaaa'
print(S.count('aa'))
# Out:
# 3

# %% [markdown]
# При указании трёх параметров S.count(T, a, b), будет выполнен подсчёт числа вхождений строки T в срез S[a : b].

# %% [markdown]
# Метод replace
#
# Метод replace заменяет все вхождения одной строки на другую и возвращает полученную. При этом исходная строка не изменяется. Формат: S.replace(old, new) — заменить в строке S все вхождения подстроки old на подстроку new. Пример:

# %%
S = 'Abracadabra'
t = S.replace('ra', 'e')

print(t)
# Out:
# Abecadabe

# %%
print(S.replace('a', 'A'))
# Out:
# AbrAcAdAbrA

# %% [markdown]
# C помощью метода replace можно изменить саму строку и удалить в ней все символы, равные некоторому, следующим образом:

# %%
S = 'Abracadabra'
S = S.replace('a', '')
print(S)
# Out:
# Abrcdbr

# %% [markdown]
# Если методу replace задать третий параметр num, то заменены будут не все вхождения, а только не больше, чем первые num из них.

# %%
S ='Abracadabra'
S = S.replace('a', '', 2)
print(S)
# Out:
# Abrcdabra

# %% [markdown]
# Точно так же как метод count, метод replace работает с непересекающимися шаблонами.

# %%
S = 'aa'
S.replace('a', 'aa')
# Out:
# 'aaaa'

# %%
S = 'aaaaa'
S.replace('aa', 'a')
# Out:
# 'aaa'

# %% [markdown]
# Задача. Дана строка. Замените в этой строке все цифры 1 на слово 'one'.

# %%
s = input()

replaced_s = s.replace('1', 'one')

print(replaced_s)
# Out:
# 1 two three
# one two three

# %% [markdown]
# Задача. Дана строка, состоящая из слов, разделённых пробелами. Определите, сколько в ней слов. Используйте для решения задачи метод count.

# %%
s = input()

spaces = s.count(" ")

print(spaces + 1)
# Out:
# раз два три
# 3

# %% [markdown]
# Задача. Дана строка. Получите новую строку, вставив между всеми парами соседних символов исходной строки символ ∗.

# %%
s = input()
new_s = s.replace("", "*")[1:-1]
new_s, s
# Out:
# привет
# ('п*р*и*в*е*т', 'привет')

# %% [markdown]
# Задача. Удаление гласных из строки

# %%
s = input()

vowels = "aeiouAEIOU"
result = ""

for symb in s:
  if symb not in vowels:
    result = result + symb

print(result)
# Out:
# hello
# eo

# %%
s = input()

vowels = "aeiouAEIOU"

for symb in vowels:
  s = s.replace(symb, "")

print(s)
# Out:
# hello
# hll

# %% [markdown]
# Задача. Напишите программу, которая удалит из введенной строки все согласные.

# %%
s = input()

vowels = "aeiouAEIOU"
result = ""

for symb in s:
  if symb in vowels:
    result = result + symb

print(result)

# %% [markdown]
# Задача. Напишите программу, которая считает сколько во введенном тексте согласных, а сколько гласных и выводит отношение числа гласных к числу согласных.

# %%
s = input().replace(" ", "")

vowels = "aeiouyAEIOUY"
vowel_count = 0

for symb in s:
  if symb in vowels:
    vowel_count += 1

cons_count = len(s) - vowel_count

print(vowel_count / cons_count, cons_count, vowel_count)
print(vowel_count / len(s))
# Out:
# one two three
# 0.8333333333333334 6 5
# 0.45454545454545453

# %% [markdown]
# Задача. Напишите программу, которая считает количество цифр в строке.

# %%
s = '70'
s.isdigit()
# Out:
# True

# %%
s = input()

digit_count = 0
digits = "0123456789"

for symb in s:
  if symb in digits:
    digit_count += 1

print(digit_count)
# Out:
# 27 февраля 2025 года
# 6

# %%
s = input()

digit_count = 0

for symb in s:
  if symb.isdigit():
    digit_count += 1

print(digit_count)

# %% [markdown]
# Задача. Напишите программу, которая находит самое длинное слово в строке.

# %%
s = input()

current_word = ""
max_length = 0

for symb in s:
  print("current symbol: ", symb)
  if symb != " ":
    current_word += symb
    print("current word: ", current_word)
  else:
    print("current word len: ", len(current_word), max_length)
    if len(current_word) > max_length:
      max_length = len(current_word)
    current_word = ""

if len(current_word) > max_length:
    max_length = len(current_word)

print(max_length)
# Out:
# абракадабра ледигага
# current symbol:  а
# current word:  а
# current symbol:  б
# current word:  аб
# current symbol:  р
# current word:  абр
# current symbol:  а
# current word:  абра
# current symbol:  к
# current word:  абрак
# current symbol:  а
# current word:  абрака
# current symbol:  д
# current word:  абракад
# current symbol:  а
# current word:  абракада
# current symbol:  б
# current word:  абракадаб
# current symbol:  р
# current word:  абракадабр
# current symbol:  а
# current word:  абракадабра
# current symbol:
# current word len:  11 0
# current symbol:  л
# current word:  л
# current symbol:  е
# current word:  ле
# current symbol:  д
# current word:  лед
# current symbol:  и
# current word:  леди
# current symbol:  г
# current word:  ледиг
# current symbol:  а
# current word:  ледига
# current symbol:  г
# current word:  ледигаг
# current symbol:  а
# current word:  ледигага
# 11

# %% [markdown]
# Задача. Напишите программу, которая считывает некоторую строку и одно слово, а затем выводит, сколько раз это слово встретилось в тексте.

# %%
s = input()
word = input()

current_word = ""
word_counter = 0

for symb in s:
  print("current symbol: ", symb)
  if symb != " ":
    current_word += symb
    print("current word: ", current_word)
  else:
    if current_word == word:
      word_counter += 1
      print("+1")
    current_word = ""

if current_word == word:
    word_counter += 1

print(f'Всего {word_counter} раз слово "{word}" встретилось в строке "{s}"')
# Out:
# и раз и два и три
# и
# current symbol:  и
# current word:  и
# current symbol:
# +1
# current symbol:  р
# current word:  р
# current symbol:  а
# current word:  ра
# current symbol:  з
# current word:  раз
# current symbol:
# current symbol:  и
# current word:  и
# current symbol:
# +1
# current symbol:  д
# current word:  д
# current symbol:  в
# current word:  дв
# current symbol:  а
# current word:  два
# current symbol:
# current symbol:  и
# current word:  и
# current symbol:
# +1
# current symbol:  т
# current word:  т
# current symbol:  р
# current word:  тр
# current symbol:  и
# current word:  три
# Всего 3 раз слово "и" встретилось в строке "и раз и два и три"

# %%
s = " " + input() + " "
word = " " + input() + " "

word_counter = s.count(word)

# " и "

print(f'Всего {word_counter} раз слово "{word}" встретилось в строке "{s}"')
# Out:
# и раз и два и три
# и
# Всего 2 раз слово "и" встретилось в строке "и раз и два и три"

# %% [markdown]
# <h2>Методы работы с символами</h2>
#
# S.isdigit()
# Проверяет, состоит ли строка из цифр. Если да, возвращает True, иначе — False
#
# S.upper()
# Преобразует символы строки к верхнему регистру. Заглавные буквы и символы, которые не относятся к буквам, не меняются
#
# S.lower()
# Преобразует символы строки к нижнему регистру. Строчные буквы и символы, которые не относятся к буквам, не меняются

# %%
S ='Abracadabra'
print(S.isalpha(), S.isdigit())
# Out:
# True False

# %%
S_digit = "4835703"
S_digit.isdigit()
# Out:
# True

# %%
S_digit = "4835.703"
print(S_digit.isdigit())
s1 = int(float(S_digit))
s2 = float(S_digit)
print(s1, s2)
# Out:
# 4835 4835.703

# %%
S.upper()
# Out:
# 'ABRACADABRA'

# %%
S.lower()
# Out:
# 'abracadabra'

# %%
S
# Out:
# 'Abracadabra'

# %% [markdown]
# S.lstrip([символ])
#
# Удаляет определённые символы в начале строки. Здесь [символ] — необязательный аргумент. Если он не задан, метод удаляет пробелы
#
# S.rstrip([символ])
#
# Удаляет определённые символы в конце строки. Здесь [символ] — необязательный аргумент. Если он не задан, метод удаляет пробелы
#
# S.strip([символ])
# Делает то же самое с обеих сторон

# %%
S ='    Abracadabra    '

# %%
S.lstrip()
# Out:
# 'Abracadabra    '

# %%
S.rstrip()
# Out:
# '    Abracadabra'

# %%
S.strip()
# Out:
# 'Abracadabra'

# %%
S.strip().lstrip('A')
# Out:
# 'bracadabra'

# %% [markdown]
# Задание. Напишите программу, которая принимает на вход строку, удаляет пробелы в начале и в конце и переводит все символы в нижний регистр

# %%
S = input()

print(S.strip().lower())
# Out:
#     Раз Два Три Четыре
# раз два три четыре

# %% [markdown]
# Задание: проверка сложности пароля. Напишите программу, которая проверяет, содержит ли входная строка хотя бы одну цифру, содержит ли хотя бы одну заглавную букву, содержит ли больше 8 символов. Также, пароль не должен начинаться и заканчиваться на пробел. Если пароль удовлетворяет требованиям, выведите строку "Пароль принят!", если нет - "Пароль слишком простой!"

# %%
password = input()

if password.isalpha() or password.islower() or password.isupper() or len(password) <= 8 or password.strip() != password:
  print("Пароль слишком простой!")
else:
  print("Пароль принят!")

# %% [markdown]
# Задача. Напишите программу, которая выведет количество цифр, заглавных и строчных букв и пробелов для введенной строки.

# %%
s = input()

digit_count = 0
upper_count = 0
lower_count = 0
space_count = 0
punctuation_count = 0

for symb in s:
  if symb.isdigit():
    digit_count += 1
  elif symb.isspace():
    space_count += 1
  elif symb.islower():
    lower_count += 1
  elif symb.isupper():
    upper_count += 1
  else:
    punctuation_count += 1

print(f"Всего цифр: {digit_count}, всего пробелов: {space_count}, всего заглавных: {upper_count}, всего строчных: {lower_count}, знаков препинания: {punctuation_count}")
# Out:
# Абракадабра! Леди Гага 98
# Всего цифр: 2, всего пробелов: 3, всего заглавных: 3, всего строчных: 16, знаков препинания: 1

# %%
s = "dfsdf 889"
s.islower()
# Out:
# True

# %%
s = "."
s.isupper()
# Out:
# False

# %% [markdown]
# Задача. Напишите программу, которая переводит строку в "змеиный" регистр: все пробелы заменяются на "_", все буквы переводятся в нижний регистр.

# %%
s = input()

print(s.lower().replace(" ", "_"))
# Out:
# Mag Python 4
# mag_python_4
